# %% [markdown]
# # Strategy Details
# Reference: Terrence Hendershott, Dmitry Livdan, Dominik Rösch, "Asset pricing: A tale of night and day",
# Journal of Financial Economics,Volume 138, Issue 3,2020
#
#
# Link to reference: https://www.sciencedirect.com/science/article/abs/pii/S0304405X20301732
#
# The main idea: The idea is similar to bet against beta, but taking the Night returns into account

# %% [markdown]
# ### The part that is not same as the paper
# - The paper obtained the returns from Center for Research in Security Prices (CRSP). I am using yfinance instead
# - The paper has a larger universe of 39 countries. Here I am using US equity stock market only
# - Instead of replicating the paper from 1992-2016, I am doing it from 2014 to 2023
# - I am using top 10% and bottom 10% beta stocks

# %%
import os
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf
import statsmodels.api as sm

start_date = '2014-01-01'
end_date = '2023-12-31'

# %%
# Get the list of S&P 500 companies from Wikipedia
url = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'
response = requests.get(url)
html = response.content

df = pd.read_html(html, header=0)[0]

tickers = df['Symbol'].tolist()
tickers.append('^GSPC')

# %%
def load_data(symbol):

    direc = 'data/'
    os.makedirs(direc, exist_ok=True)

    file_name = os.path.join(direc, symbol + '.csv')

    if not os.path.exists(file_name):

        ticker = yf.Ticker(symbol)
        df = ticker.history(start= start_date, end= end_date)

        df.to_csv(file_name)

    df = pd.read_csv(file_name, index_col=0)
    df.index = pd.to_datetime(df.index, utc=True).tz_convert('US/Eastern')
    df['date'] = df.index

    if len(df) == 0:
        os.remove(file_name)
        return None

    return df

# %%
holder = []
ticker_with_data = []
for symbol in tickers:
    df = load_data(symbol)
    if df is not None:
        holder.append(df)
        ticker_with_data.append(symbol)

tickers = ticker_with_data[:]

print (f'Loaded data for {len(tickers)} companies')
# Out:
# BRK.B: No timezone found, symbol may be delisted
# BF.B: No price data found, symbol may be delisted (1d 2014-01-01 -> 2023-12-31)
# GEV: Data doesn't exist for startDate = 1388552400, endDate = 1703998800
# SOLV: Data doesn't exist for startDate = 1388552400, endDate = 1703998800
# Loaded data for 500 companies

# %%
#keep the Opening and Closing for calculating close-to-close returns and open-to-close returns
for stocks in holder:
    #open to close returns or Day returns
    stocks['Open_to_Close'] = (stocks['Close'] - stocks['Open']) / stocks['Open']
    #close to close returns
    #As yfinance did not provde close to close return as CRSP did, we calculate it by ourselves
    #Note that the close-to-close returns around holidays and weekends can be longer than 24 h.
    stocks['Close_to_Close'] = stocks['Close'].pct_change()     
    #Night returns
    stocks['Night_returns'] = (1+stocks['Close_to_Close']) / (1+stocks['Open_to_Close']) - 1

# %% [markdown]
# ### Estimate beta by regressing the Night returns

# %%
def calculate_beta(stock_returns, market_returns):
    model = sm.OLS(stock_returns, sm.add_constant(market_returns))
    results = model.fit()
    beta = results.params.values[1]
    return beta


def add_beta(ticker_data, market_data):
    period = 252
    beta_holder = {}

    merged_df = pd.merge(
        ticker_data['Night_returns'],
        market_data['Night_returns'],
        how = 'left',
        left_index=True, right_index=True,
        suffixes=('_stock', '_market')
        )
    merged_df.dropna(inplace=True)


    for i, date in enumerate(merged_df.index):
        if i < period:
            continue
        
        #for the day i-period to i-1 , we calculate the beta based on the past 252 days
        stock_returns = merged_df.iloc[i-period:i]['Night_returns_stock']
        market_returns = merged_df.iloc[i-period:i]['Night_returns_market']

        beta = calculate_beta(stock_returns, market_returns)
        beta_holder[date] = beta

    beta_holder = pd.Series(beta_holder)
    beta_holder.name = 'Beta'
    beta_holder.index = pd.to_datetime(beta_holder.index, utc=True)
    beta_holder.index = beta_holder.index.tz_convert('US/Eastern')

    # Merge the beta with the original data
    ticker_data = pd.merge(ticker_data, beta_holder, how='left', left_index=True, right_index=True)

    return ticker_data


tickers_data = holder[0:-1]
market_data = holder[-1]

for ticker_index in range(len(tickers_data)):
    tickers_data[ticker_index] = add_beta(tickers_data[ticker_index] , market_data)
    print (tickers[ticker_index], "is about to be processed.")
# Out:
# MMM is about to be processed.
# AOS is about to be processed.
# ABT is about to be processed.
# ABBV is about to be processed.
# ACN is about to be processed.
# ADBE is about to be processed.
# AMD is about to be processed.
# AES is about to be processed.
# AFL is about to be processed.
# A is about to be processed.
# APD is about to be processed.
# ABNB is about to be processed.
# AKAM is about to be processed.
# ALB is about to be processed.
# ARE is about to be processed.
# ALGN is about to be processed.
# ALLE is about to be processed.
# LNT is about to be processed.
# ALL is about to be processed.
# GOOGL is about to be processed.
# GOOG is about to be processed.
# MO is about to be processed.
# AMZN is about to be processed.
# AMCR is about to be processed.
# AEE is about to be processed.
# AAL is about to be processed.
# AEP is about to be processed.
# AXP is about to be processed.
# AIG is about to be processed.
# AMT is about to be processed.
# AWK is about to be processed.
# AMP is about to be processed.
# AME is about to be processed.
# AMGN is about to be processed.
# APH is about to be processed.
# ADI is about to be processed.
# ANSS is about to be processed.
# AON is about to be processed.
# APA is about to be processed.
# AAPL is about to be processed.
# AMAT is about to be processed.
# APTV is about to be processed.
# ACGL is about to be processed.
# ADM is about to be processed.
# ANET is about to be processed.
# AJG is about to be processed.
# AIZ is about to be processed.
# T is about to be processed.
# ATO is about to be processed.
# ADSK is about to be processed.
# ADP is about to be processed.
# AZO is about to be processed.
# AVB is about to be processed.
# AVY is about to be processed.
# AXON is about to be processed.
# BKR is about to be processed.
# BALL is about to be processed.
# BAC is about to be processed.
# BK is about to be processed.
# BBWI is about to be processed.
# BAX is about to be processed.
# BDX is about to be processed.
# BBY is about to be processed.
# BIO is about to be processed.
# TECH is about to be processed.
# BIIB is about to be processed.
# BLK is about to be processed.
# BX is about to be processed.
# BA is about to be processed.
# BKNG is about to be processed.
# BWA is about to be processed.
# BXP is about to be processed.
# BSX is about to be processed.
# BMY is about to be processed.
# AVGO is about to be processed.
# BR is about to be processed.
# BRO is about to be processed.
# BLDR is about to be processed.
# BG is about to be processed.
# CDNS is about to be processed.
# CZR is about to be processed.
# CPT is about to be processed.
# CPB is about to be processed.
# COF is about to be processed.
# CAH is about to be processed.
# KMX is about to be processed.
# CCL is about to be processed.
# CARR is about to be processed.
# CTLT is about to be processed.
# CAT is about to be processed.
# CBOE is about to be processed.
# CBRE is about to be processed.
# CDW is about to be processed.
# CE is about to be processed.
# COR is about to be processed.
# CNC is about to be processed.
# CNP is about to be processed.
# CF is about to be processed.
# CHRW is about to be processed.
# CRL is about to be processed.
# SCHW is about to be processed.
# CHTR is about to be processed.
# CVX is about to be processed.
# CMG is about to be processed.
# CB is about to be processed.
# CHD is about to be processed.
# CI is about to be processed.
# CINF is about to be processed.
# CTAS is about to be processed.
# CSCO is about to be processed.
# C is about to be processed.
# CFG is about to be processed.
# CLX is about to be processed.
# CME is about to be processed.
# CMS is about to be processed.
# KO is about to be processed.
# CTSH is about to be processed.
# CL is about to be processed.
# CMCSA is about to be processed.
# CAG is about to be processed.
# COP is about to be processed.
# ED is about to be processed.
# STZ is about to be processed.
# CEG is about to be processed.
# COO is about to be processed.
# CPRT is about to be processed.
# GLW is about to be processed.
# CPAY is about to be processed.
# CTVA is about to be processed.
# CSGP is about to be processed.
# COST is about to be processed.
# CTRA is about to be processed.
# CRWD is about to be processed.
# CCI is about to be processed.
# CSX is about to be processed.
# CMI is about to be processed.
# CVS is about to be processed.
# DHR is about to be processed.
# DRI is about to be processed.
# DVA is about to be processed.
# DAY is about to be processed.
# DECK is about to be processed.
# DE is about to be processed.
# DAL is about to be processed.
# DVN is about to be processed.
# DXCM is about to be processed.
# FANG is about to be processed.
# DLR is about to be processed.
# DFS is about to be processed.
# DG is about to be processed.
# DLTR is about to be processed.
# D is about to be processed.
# DPZ is about to be processed.
# DOV is about to be processed.
# DOW is about to be processed.
# DHI is about to be processed.
# DTE is about to be processed.
# DUK is about to be processed.
# DD is about to be processed.
# EMN is about to be processed.
# ETN is about to be processed.
# EBAY is about to be processed.
# ECL is about to be processed.
# EIX is about to be processed.
# EW is about to be processed.
# EA is about to be processed.
# ELV is about to be processed.
# LLY is about to be processed.
# EMR is about to be processed.
# ENPH is about to be processed.
# ETR is about to be processed.
# EOG is about to be processed.
# EPAM is about to be processed.
# EQT is about to be processed.
# EFX is about to be processed.
# EQIX is about to be processed.
# EQR is about to be processed.
# ESS is about to be processed.
# EL is about to be processed.
# ETSY is about to be processed.
# EG is about to be processed.
# EVRG is about to be processed.
# ES is about to be processed.
# EXC is about to be processed.
# EXPE is about to be processed.
# EXPD is about to be processed.
# EXR is about to be processed.
# XOM is about to be processed.
# FFIV is about to be processed.
# FDS is about to be processed.
# FICO is about to be processed.
# FAST is about to be processed.
# FRT is about to be processed.
# FDX is about to be processed.
# FIS is about to be processed.
# FITB is about to be processed.
# FSLR is about to be processed.
# FE is about to be processed.
# FI is about to be processed.
# FMC is about to be processed.
# F is about to be processed.
# FTNT is about to be processed.
# FTV is about to be processed.
# FOXA is about to be processed.
# FOX is about to be processed.
# BEN is about to be processed.
# FCX is about to be processed.
# GRMN is about to be processed.
# IT is about to be processed.
# GE is about to be processed.
# GEHC is about to be processed.
# GEN is about to be processed.
# GNRC is about to be processed.
# GD is about to be processed.
# GIS is about to be processed.
# GM is about to be processed.
# GPC is about to be processed.
# GILD is about to be processed.
# GPN is about to be processed.
# GL is about to be processed.
# GDDY is about to be processed.
# GS is about to be processed.
# HAL is about to be processed.
# HIG is about to be processed.
# HAS is about to be processed.
# HCA is about to be processed.
# DOC is about to be processed.
# HSIC is about to be processed.
# HSY is about to be processed.
# HES is about to be processed.
# HPE is about to be processed.
# HLT is about to be processed.
# HOLX is about to be processed.
# HD is about to be processed.
# HON is about to be processed.
# HRL is about to be processed.
# HST is about to be processed.
# HWM is about to be processed.
# HPQ is about to be processed.
# HUBB is about to be processed.
# HUM is about to be processed.
# HBAN is about to be processed.
# HII is about to be processed.
# IBM is about to be processed.
# IEX is about to be processed.
# IDXX is about to be processed.
# ITW is about to be processed.
# INCY is about to be processed.
# IR is about to be processed.
# PODD is about to be processed.
# INTC is about to be processed.
# ICE is about to be processed.
# IFF is about to be processed.
# IP is about to be processed.
# IPG is about to be processed.
# INTU is about to be processed.
# ISRG is about to be processed.
# IVZ is about to be processed.
# INVH is about to be processed.
# IQV is about to be processed.
# IRM is about to be processed.
# JBHT is about to be processed.
# JBL is about to be processed.
# JKHY is about to be processed.
# J is about to be processed.
# JNJ is about to be processed.
# JCI is about to be processed.
# JPM is about to be processed.
# JNPR is about to be processed.
# K is about to be processed.
# KVUE is about to be processed.
# KDP is about to be processed.
# KEY is about to be processed.
# KEYS is about to be processed.
# KMB is about to be processed.
# KIM is about to be processed.
# KMI is about to be processed.
# KKR is about to be processed.
# KLAC is about to be processed.
# KHC is about to be processed.
# KR is about to be processed.
# LHX is about to be processed.
# LH is about to be processed.
# LRCX is about to be processed.
# LW is about to be processed.
# LVS is about to be processed.
# LDOS is about to be processed.
# LEN is about to be processed.
# LIN is about to be processed.
# LYV is about to be processed.
# LKQ is about to be processed.
# LMT is about to be processed.
# L is about to be processed.
# LOW is about to be processed.
# LULU is about to be processed.
# LYB is about to be processed.
# MTB is about to be processed.
# MRO is about to be processed.
# MPC is about to be processed.
# MKTX is about to be processed.
# MAR is about to be processed.
# MMC is about to be processed.
# MLM is about to be processed.
# MAS is about to be processed.
# MA is about to be processed.
# MTCH is about to be processed.
# MKC is about to be processed.
# MCD is about to be processed.
# MCK is about to be processed.
# MDT is about to be processed.
# MRK is about to be processed.
# META is about to be processed.
# MET is about to be processed.
# MTD is about to be processed.
# MGM is about to be processed.
# MCHP is about to be processed.
# MU is about to be processed.
# MSFT is about to be processed.
# MAA is about to be processed.
# MRNA is about to be processed.
# MHK is about to be processed.
# MOH is about to be processed.
# TAP is about to be processed.
# MDLZ is about to be processed.
# MPWR is about to be processed.
# MNST is about to be processed.
# MCO is about to be processed.
# MS is about to be processed.
# MOS is about to be processed.
# MSI is about to be processed.
# MSCI is about to be processed.
# NDAQ is about to be processed.
# NTAP is about to be processed.
# NFLX is about to be processed.
# NEM is about to be processed.
# NWSA is about to be processed.
# NWS is about to be processed.
# NEE is about to be processed.
# NKE is about to be processed.
# NI is about to be processed.
# NDSN is about to be processed.
# NSC is about to be processed.
# NTRS is about to be processed.
# NOC is about to be processed.
# NCLH is about to be processed.
# NRG is about to be processed.
# NUE is about to be processed.
# NVDA is about to be processed.
# NVR is about to be processed.
# NXPI is about to be processed.
# ORLY is about to be processed.
# OXY is about to be processed.
# ODFL is about to be processed.
# OMC is about to be processed.
# ON is about to be processed.
# OKE is about to be processed.
# ORCL is about to be processed.
# OTIS is about to be processed.
# PCAR is about to be processed.
# PKG is about to be processed.
# PANW is about to be processed.
# PARA is about to be processed.
# PH is about to be processed.
# PAYX is about to be processed.
# PAYC is about to be processed.
# PYPL is about to be processed.
# PNR is about to be processed.
# PEP is about to be processed.
# PFE is about to be processed.
# PCG is about to be processed.
# PM is about to be processed.
# PSX is about to be processed.
# PNW is about to be processed.
# PNC is about to be processed.
# POOL is about to be processed.
# PPG is about to be processed.
# PPL is about to be processed.
# PFG is about to be processed.
# PG is about to be processed.
# PGR is about to be processed.
# PLD is about to be processed.
# PRU is about to be processed.
# PEG is about to be processed.
# PTC is about to be processed.
# PSA is about to be processed.
# PHM is about to be processed.
# QRVO is about to be processed.
# PWR is about to be processed.
# QCOM is about to be processed.
# DGX is about to be processed.
# RL is about to be processed.
# RJF is about to be processed.
# RTX is about to be processed.
# O is about to be processed.
# REG is about to be processed.
# REGN is about to be processed.
# RF is about to be processed.
# RSG is about to be processed.
# RMD is about to be processed.
# RVTY is about to be processed.
# ROK is about to be processed.
# ROL is about to be processed.
# ROP is about to be processed.
# ROST is about to be processed.
# RCL is about to be processed.
# SPGI is about to be processed.
# CRM is about to be processed.
# SBAC is about to be processed.
# SLB is about to be processed.
# STX is about to be processed.
# SRE is about to be processed.
# NOW is about to be processed.
# SHW is about to be processed.
# SPG is about to be processed.
# SWKS is about to be processed.
# SJM is about to be processed.
# SNA is about to be processed.
# SO is about to be processed.
# LUV is about to be processed.
# SWK is about to be processed.
# SBUX is about to be processed.
# STT is about to be processed.
# STLD is about to be processed.
# STE is about to be processed.
# SYK is about to be processed.
# SMCI is about to be processed.
# SYF is about to be processed.
# SNPS is about to be processed.
# SYY is about to be processed.
# TMUS is about to be processed.
# TROW is about to be processed.
# TTWO is about to be processed.
# TPR is about to be processed.
# TRGP is about to be processed.
# TGT is about to be processed.
# TEL is about to be processed.
# TDY is about to be processed.
# TFX is about to be processed.
# TER is about to be processed.
# TSLA is about to be processed.
# TXN is about to be processed.
# TXT is about to be processed.
# TMO is about to be processed.
# TJX is about to be processed.
# TSCO is about to be processed.
# TT is about to be processed.
# TDG is about to be processed.
# TRV is about to be processed.
# TRMB is about to be processed.
# TFC is about to be processed.
# TYL is about to be processed.
# TSN is about to be processed.
# USB is about to be processed.
# UBER is about to be processed.
# UDR is about to be processed.
# ULTA is about to be processed.
# UNP is about to be processed.
# UAL is about to be processed.
# UPS is about to be processed.
# URI is about to be processed.
# UNH is about to be processed.
# UHS is about to be processed.
# VLO is about to be processed.
# VTR is about to be processed.
# VLTO is about to be processed.
# VRSN is about to be processed.
# VRSK is about to be processed.
# VZ is about to be processed.
# VRTX is about to be processed.
# VTRS is about to be processed.
# VICI is about to be processed.
# V is about to be processed.
# VST is about to be processed.
# VMC is about to be processed.
# WRB is about to be processed.
# GWW is about to be processed.
# WAB is about to be processed.
# WBA is about to be processed.
# WMT is about to be processed.
# DIS is about to be processed.
# WBD is about to be processed.
# WM is about to be processed.
# WAT is about to be processed.
# WEC is about to be processed.
# WFC is about to be processed.
# WELL is about to be processed.
# WST is about to be processed.
# WDC is about to be processed.
# WRK is about to be processed.
# WY is about to be processed.
# WMB is about to be processed.
# WTW is about to be processed.
# WYNN is about to be processed.
# XEL is about to be processed.
# XYL is about to be processed.
# YUM is about to be processed.
# ZBRA is about to be processed.
# ZBH is about to be processed.
# ZTS is about to be processed.

# %% [markdown]
# ### Trading Strategy Overview
# Long low-beta stocks by shorting high-beta stocks when markets opens (Day returns)
#
# Long high-beta stocks by shorting low-beta stocks when markets closes (Night returns)
#
#
# The trading amount is based on the difference between its beta and the sample average beta
#
# The Beta here is estimated by night returns

# %%
beta_df = pd.DataFrame()
for i in range(len(tickers_data)):
    beta_df = pd.concat([beta_df, tickers_data[i]['Beta']], axis=1)
beta_df.columns = tickers[:-1]
beta_df = beta_df[253:] 

Night_returns_df = pd.DataFrame()
for i in range(len(tickers_data)):
    Night_returns_df = pd.concat([Night_returns_df, tickers_data[i]['Night_returns']], axis=1)
Night_returns_df.columns = tickers[:-1]
Night_returns_df = Night_returns_df[253:]

Day_returns_df = pd.DataFrame()
for i in range(len(tickers_data)):
    Day_returns_df = pd.concat([Day_returns_df, tickers_data[i]['Open_to_Close']], axis=1)
Day_returns_df.columns = tickers[:-1]
Day_returns_df = Day_returns_df[253:]

# %%
def get_extreme_beta_stocks(beta_df , i):
    row = beta_df.iloc[i]
    bottom_10 = row.quantile(0.1)
    top_10 = row.quantile(0.9)

    bottom_10_stocks = row[row <= bottom_10].index.tolist()
    top_10_stocks = row[row >= top_10].index.tolist()

    return top_10_stocks, bottom_10_stocks

def get_daily_return(beta_df):
    Day_returns_holder = []
    Night_returns_holder = []
    for i in range(len(beta_df)):
        daily_top10, daily_bottom10 = get_extreme_beta_stocks(beta_df , i)
        daily_average_beta = beta_df.loc[beta_df.index[i], daily_top10 + daily_bottom10].mean()

        high_beta_amount = (beta_df.loc[beta_df.index[i], daily_top10] - daily_average_beta)/daily_average_beta
        low_beta_amount = (beta_df.loc[beta_df.index[i], daily_bottom10] - daily_average_beta)/daily_average_beta

        #Day returns, i+1 as we are using the estimated betas for the next day
        high_beta_day_returns = (Day_returns_df.loc[Day_returns_df.index[i], daily_top10]* -high_beta_amount).sum()
        low_beta_day_returns = (Day_returns_df.loc[Day_returns_df.index[i], daily_bottom10]* -low_beta_amount).sum()
        Day_returns_holder.append(high_beta_day_returns + low_beta_day_returns)    

        #Night returns, i+1 as we are using the estimated betas for the next day
        high_beta_night_returns = (Night_returns_df.loc[Night_returns_df.index[i], daily_top10] * high_beta_amount).sum()
        low_beta_night_returns = (Night_returns_df.loc[Night_returns_df.index[i], daily_bottom10] * low_beta_amount).sum()
        Night_returns_holder.append(high_beta_night_returns + low_beta_night_returns)

    return Day_returns_holder, Night_returns_holder


Day_returns_holder, Night_returns_holder = get_daily_return(beta_df)

# %% [markdown]
# ### Results

# %%
Returns_df = pd.DataFrame(Day_returns_holder)
Returns_df.index = beta_df.index
Returns_df.columns = ['Day_returns']
Returns_df['Night_returns'] = Night_returns_holder
Returns_df['Total_returns'] = Returns_df['Day_returns'] + Returns_df['Night_returns']

#The returns are not based on the initial investment amount
Returns_df['Cumulative_returns'] = Returns_df['Total_returns'].cumsum() 

#Sharpe
Day_Sharpe = Returns_df['Day_returns'].mean() / Returns_df['Day_returns'].std()
Night_Sharpe = Returns_df['Night_returns'].mean() / Returns_df['Night_returns'].std()
Total_Sharpe = Returns_df['Total_returns'].mean() / Returns_df['Total_returns'].std()
print(f"Day Sharpe: {Day_Sharpe}")
print(f"Night Sharpe: {Night_Sharpe}")
print(f"Total Sharpe: {Total_Sharpe}")
# Out:
# Day Sharpe: -0.0027830894123435524
# Night Sharpe: 0.05104321250025269
# Total Sharpe: 0.02680390430550792

# %%
plt.figure(figsize=(10, 5))
plt.plot(Returns_df['Cumulative_returns'], label='Day + Night returns')
plt.title(f'Cumulative returns for the strategy')
plt.legend()
plt.show()
plt.close()

# %%
#plot the returns
plt.figure(figsize=(10, 5))
plt.plot(Returns_df['Day_returns'], label='Day returns')
plt.title(f'Day returns')
plt.legend()
plt.show()
plt.close()

#plot the returns
plt.figure(figsize=(10, 5))
plt.plot(Returns_df['Night_returns'], label='Night returns')
plt.title(f'Night returns')
plt.legend()
plt.show()
plt.close()

# %% [markdown]
# # Final Thought
# - The Day returns show a negative returns, unlike what the paper observe from 1992 - 2016.
# - It is better to invest during the night time only.
#
# However:
# - The calculation of Night Returns is infeasible in reality, we can not get the actual "Closing Price" of the day
# - The "Zero cost" trading is under the condition that no trading fees are incurred while it is not true in reality
# - The strategy is too risky and unreliable
# - Better invest with other strategies
